# %%
import xarray as xr

# %%
# !ls /Users/brianmapes/Box/EUREC4A_SATELLITE/GOES/aeris/eurec4a-data/SATELLITES/GOES-E/2km_10min/2020/2020_01_22/
# Out:
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220000166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220010166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220020166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220030166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220040166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220050166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220100166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220110166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220120166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220130166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220140166_BARBADOS-2KM-FD.level2.nc
# clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220150166_BARBADOS-2KM-FD.level2.nc
# ...

# %%
file='/Users/brianmapes/Box/EUREC4A_SATELLITE/GOES/aeris/eurec4a-data/SATELLITES/GOES-E/2km_10min/2020/2020_01_22/clavrx_OR_ABI-L1b-RadF-M6C01_G16_s20200220000166_BARBADOS-2KM-FD.level2.nc'

# %%
ds = xr.open_dataset(file)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                            (scan_lines_along_track_direction: 531,
#                                         pixel_elements_along_scan_direction: 658,
#                                         the_third_dimension: 500)
# Coordinates:
#     latitude                           (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     longitude                          (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
# Dimensions without coordinates: scan_lines_along_track_direction,
#                                 pixel_elements_along_scan_direction,
#                                 the_third_dimension
# Data variables: (12/93)
#     scan_line_number                   (scan_lines_along_track_direction) float64 ...
#     scan_line_time                     (scan_lines_along_track_direction) timedelta64[ns] ...
# ...

# %%
ds.temp_11_0um_nom.plot(cmap='gray_r')

# %%
ds.data_vars
# Out:
# Data variables:
#     scan_line_number                   (scan_lines_along_track_direction) float64 ...
#     scan_line_time                     (scan_lines_along_track_direction) timedelta64[ns] ...
#     bad_pixel_mask                     (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     latitude_pc                        (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     longitude_pc                       (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     sensor_zenith_angle                (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     solar_zenith_angle                 (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
#     relative_azimuth_angle             (scan_lines_along_track_direction, pixel_elements_along_scan_direction) float32 ...
# ...
