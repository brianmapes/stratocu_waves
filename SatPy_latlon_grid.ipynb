# %%
# CONDA_SUBDIR=osx-64  conda create -c conda-forge -n my_satpy_env python satpy jupyterlab

# %%
import satpy
import pyresample.geometry

# %%
import pyresample.geometry

# %%
import pandas as pd

# %%
import xarray as xr

pathname = '/Users/bmapes/Box/GOES2go_satellite_downloads/Oct2023/noaa-goes16/ABI-L2-CMIPF_WINDOW-IR/2023/300/15/'
filename = 'OR_ABI-L2-CMIPF-M6C13_G16_s20233001520210_e20233001529531_c20233001529598.nc'
ds = xr.open_dataset(pathname+filename)
ds
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# <xarray.Dataset>
# Dimensions:                                           (y: 5424, x: 5424,
#                                                        number_of_time_bounds: 2,
#                                                        number_of_image_bounds: 2,
#                                                        band: 1)
# Coordinates:
#     t                                                 datetime64[ns] ...
# ...

# %%
# !ls /Users/bmapes/Box/GOES2go_satellite_downloads/Oct2023/noaa-goes16/ABI-L2-CMIPF_WINDOW-IR/2023/300/15/
# Out:
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001500210_e20233001509530_c20233001509591.nc
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001510210_e20233001519530_c20233001519586.nc
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001520210_e20233001529531_c20233001529598.nc
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001530210_e20233001539530_c20233001539593.nc
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001540210_e20233001549531_c20233001549593.nc
# OR_ABI-L2-CMIPF-M6C13_G16_s20233001550210_e20233001559530_c20233001559593.nc
